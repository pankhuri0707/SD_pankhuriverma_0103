# %% [markdown]
# <a href="https://colab.research.google.com/github/pankhuri0707/SD_pankhuriverma_0103/blob/main/math%2Crandom%2Cdetcline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

# %%
num=25
print(math.sqrt(num))
# Out:
# 5.0

# %%
n=25
print(math.cbrt(n))
# Out:
# 2.924017738212866

# %%
n=5
print(math.pow(n,3))
# Out:
# 125.0

# %%
n=4
print(math.pow(n,2))
# Out:
# 16.0

# %%
print(math.ceil(4.2))
# Out:
# 5

# %%
print(math.floor(4.9))
# Out:
# 4

# %%
print(abs(-50))
# Out:
# 50

# %%
print(math.gcd(24,36))
# Out:
# 12

# %%
print(math.lcm(12,18))
# Out:
# 36

# %%
print(math.pi)
# Out:
# 3.141592653589793

# %%
print(math.e)
# Out:
# 2.718281828459045

# %%
print(math.sin(math.radians(90)))
# Out:
# 1.0

# %%
print(math.cos(math.radians(120)))
# Out:
# -0.4999999999999998

# %%
print(math.tan(math.radians(45)))
# Out:
# 0.9999999999999999

# %%
print(math.log10(100))
# Out:
# 2.0

# %%
import random
print(random.randint(1,10))
# Out:
# 1

# %%
print(math.log(100))
# Out:
# 4.605170185988092

# %%
import random

# %%
print(random.random()) #b/w 0-1
# Out:
# 0.7369439046779931

# %%
print(random.randrange(1,100))
# Out:
# 73

# %%
fruits=["apple","banana","orange"]
print(random.choice(fruits))
# Out:
# apple

# %%
n=[1,2,3,4,5]
random.shuffle(n)
print(n)
# Out:
# [3, 1, 2, 4, 5]

# %%
print(random.uniform(1,10)) #float value
# Out:
# 6.343970488782523

# %%
print(random.choice([True,False]))
# Out:
# False

# %%
import datetime
print(datetime.datetime.now())
# Out:
# 2026-07-20 06:25:18.418958

# %%
import datetime

# %%
print(datetime.date.today())
# Out:
# 2026-07-20

# %%
print(datetime.datetime.now().time())
# Out:
# 06:28:41.164571

# %%
print(datetime.datetime.now().year)
# Out:
# 2026

# %%
print(datetime.datetime.now().month)
# Out:
# 7

# %%
print(datetime.datetime.now().day)
# Out:
# 20

# %%
print(datetime.datetime.now().hour)
# Out:
# 6

# %%
print(datetime.datetime.now().minute)
# Out:
# 36

# %%
print(datetime.datetime.now().second)
# Out:
# 29

# %%
#custom
d=datetime.date(2026,7,19)
print(d)
# Out:
# 2026-07-19

# %%
t=datetime.time(10,30,45)
print(t)
# Out:
# 10:30:45

# %%
date1=datetime.date(2026,7,29)
date2=datetime.date(2026,8,19)
print(date2-date1)
# Out:
# 21 days, 0:00:00

# %%
today=datetime.datetime.now()
print(today.strftime("%d-%m-%y"))
# Out:
# 20-07-26

# %%
now=datetime.datetime.now()
print(today.strftime("%H-%M-%S"))
# Out:
# 06-49-03

# %%
today=datetime.datetime.now()
print(today.strftime("%A"))
# Out:
# Monday

# %%
today=datetime.datetime.now()
print(today.strftime("%B"))
# Out:
# July

# %%
import time
from IPython.display import clear_output
from datetime import datetime
while True:
  clear_output(wait=True)
  current_time = datetime.now().strftime("%I:%M:%S:%p")
  print("    DIGITAL CLOCK     ")
  print(current_time)
  time.sleep(1)
# Out:
#     DIGITAL CLOCK
# 09:03:41:AM
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_4426/771007639.py in <cell line: 0>()
#       7   print("    DIGITAL CLOCK     ")
#       8   print(current_time)
# ----> 9   time.sleep(1)
#
# KeyboardInterrupt:

# %%
import time
from IPython.display import clear_output
from datetime import datetime
from zoneinfo import ZoneInfo
while True:
    clear_output(wait=True)

    ist_time=datetime.now(ZoneInfo("Asia/Kolkata"))
    print("Digital Clock")
    print("Date:",ist_time.strftime("%d-%m-%y"))
    print("Day:",ist_time.strftime("%A"))
    print("Time:",ist_time.strftime("%I:%M:%S:%p"))
    print("Zone:","Indian Standard Time(IST)")
    time.sleep(1)
# Out:
# Digital Clock
# Date: 20-07-26
# Day: Monday
# Time: 02:49:49:PM
# Zone: Indian Standard Time(IST)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_4426/3526558411.py in <cell line: 0>()
#      12     print("Time:",ist_time.strftime("%I:%M:%S:%p"))
#      13     print("Zone:","Indian Standard Time(IST)")
# ---> 14     time.sleep(1)
#
# KeyboardInterrupt:
