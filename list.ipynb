# %% [markdown]
# <a href="https://colab.research.google.com/github/pankhuri0707/SD_pankhuriverma_0103/blob/main/list.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nums=[1,2,3,4]

# %%
nums[0]
# Out:
# 1

# %%
nums[2]
# Out:
# 3

# %%
nums[4]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_692/2255194133.py in <cell line: 0>()
# ----> 1 nums[4]
#
# IndexError: list index out of range

# %%
type(nums)
# Out:
# list

# %%
data=["pankhuri",19,"SRMCEM",8.5,"My first project",8,'a',9.0,257.9,"purple"]

# %%
data[0:11:2]
# Out:
# ['pankhuri', 'SRMCEM', 'My first project', 'a', 257.9]

# %%
l=[1,345,45,"pankhuri",True,5+7j,345.789]

# %%
l[5].real
# Out:
# 5.0

# %%
l[::2]
# Out:
# [1, 45, True, 345.789]

# %%
l[0:5:3]
# Out:
# [1, 'pankhuri']

# %%
l[::8]
# Out:
# [1]

# %%
l[::4]
# Out:
# [1, True]

# %%
l
# Out:
# [1, 345, 45, 'pankhuri', True, (5+7j), 345.789]

# %%
l[-1]
# Out:
# 345.789

# %%
l[-1:-5:-2]
# Out:
# [345.789, True]

# %%
l[-1:-5:2]
# Out:
# []

# %%
s="pankhuri"

# %%
l+s
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1999/1140923193.py in <cell line: 0>()
# ----> 1 l+s
#
# TypeError: can only concatenate list (not "str") to list

# %%
list(s)+l
# Out:
# ['p',
#  'a',
#  'n',
#  'k',
#  'h',
#  'u',
#  'r',
#  'i',
#  1,
#  345,
#  45,
#  'pankhuri',
#  True,
#  (5+7j),
#  345.789,
#  1,
#  1]

# %%
l
# Out:
# [1, 345, 45, 'pankhuri', True, (5+7j), 345.789, 1, 1, 3, 3]

# %%
l1=[1,2,3,4,5]

# %%
l1
# Out:
# [1, 2, 3, 4, 5]

# %%
l1.append(2)

# %%
l1
# Out:
# [1, 2, 3, 4, 5]

# %%
l2=[1,345,45,"sudh",True,5+7j,345.789]

# %%
l2[3][0:2]
# Out:
# 'su'

# %%
str(l[4])[0:2]
# Out:
# 'Tr'

# %%
s=str(l2[3])

# %%
s[0:2]
# Out:
# 'su'

# %%
l2.insert(2,8)

# %%
l2
# Out:
# [1, 345, 8, 45, 'sudh', True, (5+7j), 345.789]

# %%
l2.remove(8)

# %%
l2
# Out:
# [1, 345, 45, 'sudh', True, (5+7j), 345.789]

# %%
a=input("my name is")
# Out:
# my name ispankhuri

# %%
a
# Out:
# 'pankhuri'

# %%
b=int(input("my percentage is:"))
# Out:
# my percentage is:56

# %%
b
# Out:
# 56

# %%
x="10"
y=int(x)
y
# Out:
# 10

# %%
x="3.14"
y=float(x)
y
# Out:
# 3.14

# %%
x=25
y=str(x)
y
# Out:
# '25'

# %%
l=(1,2,3)
y=list(l)
y
# Out:
# [1, 2, 3]

# %%
x=[1,2,3]
y=tuple(x)
y
# Out:
# (1, 2, 3)
