# %% [markdown]
# <a href="https://colab.research.google.com/github/pankhuri0707/SD_pankhuriverma_0103/blob/main/Dictionary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
d={0:"pankhuri",1:19,2:"SRMCEM",3:103}

# %%
d[0]
# Out:
# 'pankhuri'

# %%
a=int(input("marks of pysics"))
b=int(input("marks of chem "))
c=int(input("marks of maths"))
# Out:
# marks of pysics89
# marks of chem 76
# marks of maths90

# %%
sum =(a+b+c)/3.0
sum
# Out:
# 85.0

# %%
if sum>=80:
   print("you eill be part of 40 batch")
elif sum>=60 and sum<80:
  print(" a1 batch")
elif sum>=40 and sum<60:
  print("a2 batch")
else:
  print("a3 btach")
# Out:
# you eill be part of 40 batch

# %%
for i in range(5):
 a=int(input("marks"))
 if a>=80:
  print("a")
 elif a>=60 and a<80:
  print("b")
 elif a>=40 and a<60:
  print("c")
 else:
  print("d")
# Out:
# marks33
# d
# marks67
# b
# marks78
# b
# marks66
# b
# marks90
# a
