# %% [markdown]
# <a href="https://colab.research.google.com/github/pankhuri0707/SD_pankhuriverma_0103/blob/main/conditional_control.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x=10
if x>5:
  print("x is greater than 5")
# Out:
# x is greater than 5

# %%
x=3
if x%2==0:
   print("x is even")
else:
   print("x is odd")
# Out:
# x is odd

# %%
l=[1,345,45,"sudh",True,5+7j,345.897]

# %%
l[0]
# Out:
# 1

# %%
type(l)
# Out:
# list

# %%
l[-1:-5:-2]
# Out:
# [345.897, True]

# %%
s="pankhuri"

# %%
l+s
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1038/1140923193.py in <cell line: 0>()
# ----> 1 l+s
#
# TypeError: can only concatenate list (not "str") to list

# %%
list(s)+l
# Out:
# ['p',
#  'a',
#  'n',
#  'k',
#  'h',
#  'u',
#  'r',
#  'i',
#  1,
#  345,
#  45,
#  'sudh',
#  True,
#  (5+7j),
#  345.897]

# %%
n=5

# %%
n+l
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1038/1274768168.py in <cell line: 0>()
# ----> 1 n+l
#
# TypeError: unsupported operand type(s) for +: 'int' and 'list'

# %%
l1=[1,2,3]

# %%
l1+l
# Out:
# [1, 2, 3, 1, 345, 45, 'sudh', True, (5+7j), 345.897]

# %%
l1*3
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3]

# %%
l.append(s)

# %%
l
# Out:
# [1, 345, 45, 'sudh', True, (5+7j), 345.897, 'pankhuri', 'pankhuri']

# %%
l.append(l1)

# %%
l
# Out:
# [1, 345, 45, 'sudh', True, (5+7j), 345.897, 'pankhuri', 'pankhuri', [1, 2, 3]]

# %%
l[-1][1]
# Out:
# 2

# %%
l.extend(4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1038/2311825727.py in <cell line: 0>()
# ----> 1 l.extend(4)
#
# TypeError: 'int' object is not iterable

# %%
l.extend("sudh")

# %%
l
# Out:
# [1,
#  345,
#  45,
#  'sudh',
#  True,
#  (5+7j),
#  345.897,
#  'pankhuri',
#  'pankhuri',
#  [1, 2, 3],
#  's',
#  'u',
#  'd',
#  'h']

# %%
l.extend([5,6,7])

# %%
l
# Out:
# [1,
#  345,
#  45,
#  'sudh',
#  True,
#  (5+7j),
#  345.897,
#  'pankhuri',
#  'pankhuri',
#  [1, 2, 3],
#  's',
#  'u',
#  'd',
#  'h',
#  5,
#  6,
#  7]

# %%
l.insert(1,"sam")

# %%
l
# Out:
# [1,
#  'sam',
#  'saksham',
#  345,
#  45,
#  'sudh',
#  True,
#  (5+7j),
#  345.897,
#  'pankhuri',
#  'pankhuri',
#  [1, 2, 3],
#  's',
#  'u',
#  'd',
#  'h',
#  5,
#  6,
#  7]

# %%
l
# Out:
# [1,
#  'sam',
#  345,
#  45,
#  'sudh',
#  True,
#  (5+7j),
#  345.897,
#  'pankhuri',
#  'pankhuri',
#  [1, 2, 3],
#  's',
#  'u',
#  'd',
#  'h',
#  5,
#  6,
#  7]

# %%
l.remove("sam")

# %%
l
# Out:
# [1,
#  345,
#  45,
#  'sudh',
#  True,
#  (5+7j),
#  345.897,
#  'pankhuri',
#  'pankhuri',
#  [1, 2, 3],
#  's',
#  'u',
#  'd',
#  'h',
#  5,
#  6,
#  7]

# %%
l.remove("pankhuri") #clicked 2 times

# %%
l
# Out:
# [1,
#  345,
#  45,
#  'sudh',
#  True,
#  (5+7j),
#  345.897,
#  [1, 2, 3],
#  's',
#  'u',
#  'd',
#  'h',
#  5,
#  6,
#  7]

# %%
l.reverse()

# %%
l
# Out:
# [7,
#  6,
#  5,
#  'h',
#  'd',
#  'u',
#  's',
#  [1, 2, 3],
#  345.897,
#  (5+7j),
#  True,
#  'sudh',
#  45,
#  345,
#  1]

# %%
l.sort
# Out:
# <function list.sort(*, key=None, reverse=False)>

# %%
l1=[1,3,5,2,7,9]

# %%
l1.sort()

# %%
l1
# Out:
# [1, 2, 3, 5, 7, 9]

# %%
l.count("sudh")
# Out:
# 1

# %%
l.index("sudh")
# Out:
# 11

# %%
w="hello"

# %%
w.replace("o","s")
# Out:
# 'hells'

# %%
w
# Out:
# 'hello'

# %%
t=(2,3,4,5,'sudh',45.56,False,(45+56j),[1,2,3])

# %%
type(t)
# Out:
# tuple

# %%
len(t)
# Out:
# 9

# %%
t[-1]
# Out:
# [1, 2, 3]

# %%
t.append("w")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1038/3263289268.py in <cell line: 0>()
# ----> 1 t.append("w")
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
t.remove("45.56")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1038/817940352.py in <cell line: 0>()
# ----> 1 t.remove("45.56")
#
# AttributeError: 'tuple' object has no attribute 'remove'

# %%
t.pop(3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1038/2564230587.py in <cell line: 0>()
# ----> 1 t.pop(3)
#
# AttributeError: 'tuple' object has no attribute 'pop'

# %%
t.insert("sudh")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1038/3373796716.py in <cell line: 0>()
# ----> 1 t.insert("sudh")
#
# AttributeError: 'tuple' object has no attribute 'insert'

# %%
t.delete("d")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1038/3799686653.py in <cell line: 0>()
# ----> 1 t.delete("d")
#
# AttributeError: 'tuple' object has no attribute 'delete'

# %%
t*3
# Out:
# (2,
#  3,
#  4,
#  5,
#  'sudh',
#  45.56,
#  False,
#  (45+56j),
#  [1, 2, 3],
#  2,
#  3,
#  4,
#  5,
#  'sudh',
#  45.56,
#  False,
#  (45+56j),
#  [1, 2, 3],
#  2,
#  3,
#  4,
#  5,
#  'sudh',
#  45.56,
#  False,
#  (45+56j),
#  [1, 2, 3])

# %%
d={}

# %%
type(d)
# Out:
# dict

# %%
s2={1,2,3,(8,9,7)}

# %%
type(s2)
# Out:
# set

# %%
s2=list(set(s2))

# %%
s2
# Out:
# [3, 1, 2, (8, 9, 7)]

# %%
s3={1,3,4,5,6}

# %%
s3.add(45)

# %%
s3
# Out:
# {1, 3, 4, 5, 6, 45}
